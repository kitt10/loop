# %%
import torch
import torch.nn as nn

from net_t2l import NetT2L, T2LModel
        
def load_pretrained(fn):
    return torch.load(fn)

def load_middleblock(fn):
    mod = torch.load(fn)
    mod.output_layer = nn.Identity()
    return mod

net = NetT2L()
#net = NetT2L(middleblock=load_middleblock(fn='model-intents-middleblock'))
#net = NetT2L(pretrained=load_pretrained(fn='model-intents-pretrained'))
net = NetT2L(pretrained=load_pretrained(fn='model-intents-pretrained-m4'))
# Out:
# WARNING:root:No sentence-transformers model found with name /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5 were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Required knowledge initialized: n = 768, m = 6, pt = 0, pk = 60, labels: {0: 'KALENDÁŘ', 1: 'POKYN', 2: 'POZDRAV', 3: 'POZNEJ', 4: 'STOP', 5: 'VYGOOGLI'}
# WARNING:root:No sentence-transformers model found with name /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5 were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Required knowledge initialized: n = 768, m = 6, pt = 40, pk = 60, labels: {0: 'KALENDÁŘ', 1: 'POKYN', 2: 'POZDRAV', 3: 'POZNEJ', 4: 'STOP', 5: 'VYGOOGLI'}

# %%
from time import time

def now():
    return round(time()-t0, 2)

def shot(step, phase, t=None, **dialog):
    print('D:',dialog)
    loss, acc, wrongs, oks = net.evaluate(ret_wrongs=True, ret_oks=True)
    exp[t if t == 0 else now()] = {
        'step': step,
        'phase': phase,
        'labels': net.data.labels,
        'm': net.data.m,
        'pt': {label:net.data.data['train']['labels'].count(label) for label in net.data.labels},
        'loss': loss,
        'acc': acc,
        'wrongs': wrongs,
        'oks': oks,
        'dialog': dialog
    }

print('== Training loop ==')
exp = {}
steps = 100
t0 = time()

shot(step=0, phase='init', t=0)

for step in range(1, steps+1):
    ans = ''
    correction = ''
    prompt = input('\n\n> ')
    if prompt == 'done':
        break

    shot(step=step, phase='prompted', prompt=prompt)

    ans = net.predict(prompt)

    shot(step=step, phase='answered', prompt=prompt, ans=ans)

    correction = input(f'>> Ans: {ans} / Correct class (blank if OK): ')

    shot(step=step, phase='feedbacked', prompt=prompt, ans=ans, correction=correction)

    if correction:
        net.learn(sample=prompt, label=correction, verbose=False)
        shot(step=step, phase='retrained', prompt=prompt, ans=ans, correction=correction)
    else:
        if prompt not in net.data.data['train']['samples']:
            net.learn(sample=prompt, label=ans, verbose=False)
            shot(step=step, phase='tuned', prompt=prompt, ans=ans, correction=correction)
        else:
            shot(step=step, phase='passed', prompt=prompt, ans=ans, correction=correction)

    loss, acc = net.evaluate()
    print(f'== Acc: {acc}, Loss: {loss}')
# Out:
# == Training loop ==
# D: {}
# D: {'prompt': 'Ahoj'}
# target: 1
# D: {'prompt': 'Ahoj', 'ans': 'POKYN'}
# D: {'prompt': 'Ahoj', 'ans': 'POKYN', 'correction': 'POZDRAV'}
# Final train loss: 0.3992419441541036, dev loss: 2.061050683259964
# D: {'prompt': 'Ahoj', 'ans': 'POKYN', 'correction': 'POZDRAV'}
# == Acc: 0.6666666666666666, Loss: 2.065649934858084
# D: {'prompt': 'Hlavní město Peru?'}
# target: 5
# D: {'prompt': 'Hlavní město Peru?', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Hlavní město Peru?', 'ans': 'VYGOOGLI', 'correction': ''}
# Sample Hlavní město Peru? added to train. pt = 41
# Sample Hlavní město Peru? added to dev.
# Final train loss: 0.21980224549770355, dev loss: 2.2856252789497375
# D: {'prompt': 'Hlavní město Peru?', 'ans': 'VYGOOGLI', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.284400299129387
# D: {'prompt': 'Čau'}
# target: 2
# D: {'prompt': 'Čau', 'ans': 'POZDRAV'}
# D: {'prompt': 'Čau', 'ans': 'POZDRAV', 'correction': ''}
# D: {'prompt': 'Čau', 'ans': 'POZDRAV', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.284400299129387
# D: {'prompt': 'Stop'}
# target: 4
# D: {'prompt': 'Stop', 'ans': 'STOP'}
# D: {'prompt': 'Stop', 'ans': 'STOP', 'correction': ''}
# D: {'prompt': 'Stop', 'ans': 'STOP', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.284400299129387
# D: {'prompt': 'Zastav'}
# target: 4
# D: {'prompt': 'Zastav', 'ans': 'STOP'}
# D: {'prompt': 'Zastav', 'ans': 'STOP', 'correction': ''}
# D: {'prompt': 'Zastav', 'ans': 'STOP', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.284400299129387
# D: {'prompt': 'Je dneska sobota?'}
# target: 0
# D: {'prompt': 'Je dneska sobota?', 'ans': 'KALENDÁŘ'}
# D: {'prompt': 'Je dneska sobota?', 'ans': 'KALENDÁŘ', 'correction': ''}
# Sample Je dneska sobota? added to train. pt = 42
# Sample Je dneska sobota? added to dev.
# Final train loss: 0.09039843082427979, dev loss: 2.379374235868454
# D: {'prompt': 'Je dneska sobota?', 'ans': 'KALENDÁŘ', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.4615988894055287
# D: {'prompt': 'Co je tohle?'}
# target: 0
# D: {'prompt': 'Co je tohle?', 'ans': 'KALENDÁŘ'}
# D: {'prompt': 'Co je tohle?', 'ans': 'KALENDÁŘ', 'correction': 'POZNEJ'}
# Sample Co je tohle? added to train. pt = 43
# Sample Co je tohle? added to dev.
# Final train loss: 0.05784332876404127, dev loss: 1.8060818910598755
# D: {'prompt': 'Co je tohle?', 'ans': 'KALENDÁŘ', 'correction': 'POZNEJ'}
# == Acc: 0.7333333333333333, Loss: 1.8799771361673872
# D: {'prompt': 'Co je to za předmět?'}
# target: 4
# D: {'prompt': 'Co je to za předmět?', 'ans': 'STOP'}
# D: {'prompt': 'Co je to za předmět?', 'ans': 'STOP', 'correction': 'POZNEJ'}
# Sample Co je to za předmět? added to train. pt = 44
# Sample Co je to za předmět? added to dev.
# Final train loss: 0.039416039983431496, dev loss: 1.681204680353403
# D: {'prompt': 'Co je to za předmět?', 'ans': 'STOP', 'correction': 'POZNEJ'}
# == Acc: 0.75, Loss: 1.7881863215317328
# D: {'prompt': 'Co to držím v ruce?'}
# target: 3
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ', 'correction': ''}
# Sample Co to držím v ruce? added to train. pt = 45
# Sample Co to držím v ruce? added to dev.
# Final train loss: 0.0295082771529754, dev loss: 3.091289591789246
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ', 'correction': ''}
# == Acc: 0.75, Loss: 1.8087255411936591
# D: {'prompt': 'Co teď vidíš za předmět?'}
# target: 3
# D: {'prompt': 'Co teď vidíš za předmět?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Co teď vidíš za předmět?', 'ans': 'POZNEJ', 'correction': ''}
# Sample Co teď vidíš za předmět? added to train. pt = 46
# Sample Co teď vidíš za předmět? added to dev.
# Final train loss: 0.021667926882704098, dev loss: 2.1487963140010833
# D: {'prompt': 'Co teď vidíš za předmět?', 'ans': 'POZNEJ', 'correction': ''}
# == Acc: 0.7833333333333333, Loss: 1.7681258641493818
# D: {'prompt': 'Co vidíš?'}
# target: 3
# D: {'prompt': 'Co vidíš?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Co vidíš?', 'ans': 'POZNEJ', 'correction': ''}
# Sample Co vidíš? added to train. pt = 47
# Sample Co vidíš? added to dev.
# Final train loss: 0.01779020515580972, dev loss: 1.9122392654418945
# D: {'prompt': 'Co vidíš?', 'ans': 'POZNEJ', 'correction': ''}
# == Acc: 0.7833333333333333, Loss: 1.780958354100585
# D: {'prompt': 'Poznej tento předmět.'}
# target: 3
# D: {'prompt': 'Poznej tento předmět.', 'ans': 'POZNEJ'}
# D: {'prompt': 'Poznej tento předmět.', 'ans': 'POZNEJ', 'correction': ''}
# Sample Poznej tento předmět. added to train. pt = 48
# Sample Poznej tento předmět. added to dev.
# Final train loss: 0.014236633976300558, dev loss: 2.08103534989059
# D: {'prompt': 'Poznej tento předmět.', 'ans': 'POZNEJ', 'correction': ''}
# == Acc: 0.8, Loss: 1.7916919388730699
# D: {'prompt': 'Zatoč doleva'}
# target: 4
# D: {'prompt': 'Zatoč doleva', 'ans': 'STOP'}
# D: {'prompt': 'Zatoč doleva', 'ans': 'STOP', 'correction': 'POKYN'}
# Sample Zatoč doleva added to train. pt = 49
# Sample Zatoč doleva added to dev.
# Final train loss: 0.017971007619053125, dev loss: 0.7736305147409439
# D: {'prompt': 'Zatoč doleva', 'ans': 'STOP', 'correction': 'POKYN'}
# == Acc: 0.8333333333333334, Loss: 0.7345803739114974
# D: {'prompt': 'Zablikej'}
# target: 4
# D: {'prompt': 'Zablikej', 'ans': 'STOP'}
# D: {'prompt': 'Zablikej', 'ans': 'STOP', 'correction': 'POKYN'}
# Sample Zablikej added to train. pt = 50
# Final train loss: 0.010289454134181142, dev loss: 0.4895076286047697
# D: {'prompt': 'Zablikej', 'ans': 'STOP', 'correction': 'POKYN'}
# == Acc: 0.9333333333333333, Loss: 0.34748444765961417
# D: {'prompt': 'Zapískej'}
# target: 1
# D: {'prompt': 'Zapískej', 'ans': 'POKYN'}
# D: {'prompt': 'Zapískej', 'ans': 'POKYN', 'correction': ''}
# Sample Zapískej added to train. pt = 51
# Final train loss: 0.008784790989011526, dev loss: 0.6204961240291595
# D: {'prompt': 'Zapískej', 'ans': 'POKYN', 'correction': ''}
# == Acc: 0.9333333333333333, Loss: 0.3276513903401792
# D: {'prompt': 'Jeď rovně'}
# target: 4
# D: {'prompt': 'Jeď rovně', 'ans': 'STOP'}
# D: {'prompt': 'Jeď rovně', 'ans': 'STOP', 'correction': 'POKYN'}
# Sample Jeď rovně added to train. pt = 52
# Sample Jeď rovně added to dev.
# Final train loss: 0.008038978325203061, dev loss: 0.4096107345074415
# D: {'prompt': 'Jeď rovně', 'ans': 'STOP', 'correction': 'POKYN'}
# == Acc: 0.9333333333333333, Loss: 0.305500690456635
# D: {'prompt': 'Rozsviť LED'}
# target: 4
# D: {'prompt': 'Rozsviť LED', 'ans': 'STOP'}
# D: {'prompt': 'Rozsviť LED', 'ans': 'STOP', 'correction': 'POKYN'}
# Sample Rozsviť LED added to train. pt = 53
# Final train loss: 0.007000873563811183, dev loss: 0.2196347875520587
# D: {'prompt': 'Rozsviť LED', 'ans': 'STOP', 'correction': 'POKYN'}
# == Acc: 0.95, Loss: 0.23037440171077225
# D: {'prompt': 'zastav'}
# target: 4
# D: {'prompt': 'zastav', 'ans': 'STOP'}
# D: {'prompt': 'zastav', 'ans': 'STOP', 'correction': ''}
# Sample zastav added to train. pt = 54
# Sample zastav added to dev.
# Final train loss: 0.006132426671683788, dev loss: 0.24586131405085326
# D: {'prompt': 'zastav', 'ans': 'STOP', 'correction': ''}
# == Acc: 0.95, Loss: 0.23070839248830452
# D: {'prompt': 'Kdo je prezidentem republiky?'}
# target: 3
# D: {'prompt': 'Kdo je prezidentem republiky?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Kdo je prezidentem republiky?', 'ans': 'POZNEJ', 'correction': 'VYGOOGLI'}
# Sample Kdo je prezidentem republiky? added to train. pt = 55
# Sample Kdo je prezidentem republiky? added to dev.
# Final train loss: 0.004550933837890625, dev loss: 0.2843101298436522
# D: {'prompt': 'Kdo je prezidentem republiky?', 'ans': 'POZNEJ', 'correction': 'VYGOOGLI'}
# == Acc: 0.9333333333333333, Loss: 0.23039614242734388
# D: {'prompt': 'Jaký je smysl života?'}
# target: 3
# D: {'prompt': 'Jaký je smysl života?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Jaký je smysl života?', 'ans': 'POZNEJ', 'correction': 'VYGOOGLI'}
# Sample Jaký je smysl života? added to train. pt = 56
# Sample Jaký je smysl života? added to dev.
# Final train loss: 0.0038362948689609766, dev loss: 0.3031296846456826
# D: {'prompt': 'Jaký je smysl života?', 'ans': 'POZNEJ', 'correction': 'VYGOOGLI'}
# == Acc: 0.9333333333333333, Loss: 0.2857380598279027
# D: {'prompt': 'Jak upéct bábovku?'}
# target: 5
# D: {'prompt': 'Jak upéct bábovku?', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Jak upéct bábovku?', 'ans': 'VYGOOGLI', 'correction': ''}
# Sample Jak upéct bábovku? added to train. pt = 57
# Sample Jak upéct bábovku? added to dev.
# Final train loss: 0.0034250676981173456, dev loss: 0.3019155615475029
# D: {'prompt': 'Jak upéct bábovku?', 'ans': 'VYGOOGLI', 'correction': ''}
# == Acc: 0.9333333333333333, Loss: 0.2818265251834722
# D: {'prompt': 'Jak se řekne italsky výběrčí činže?'}
# target: 5
# D: {'prompt': 'Jak se řekne italsky výběrčí činže?', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Jak se řekne italsky výběrčí činže?', 'ans': 'VYGOOGLI', 'correction': 'PŘELOŽ'}
# Required knowledge initialized: n = 768, m = 7, pt = 57, pk = 61, labels: {0: 'KALENDÁŘ', 1: 'POKYN', 2: 'POZDRAV', 3: 'POZNEJ', 4: 'PŘELOŽ', 5: 'STOP', 6: 'VYGOOGLI'}
# Sample Jak se řekne italsky výběrčí činže? added to train. pt = 58
# Final train loss: 0.05027370061725378, dev loss: 0.5263059791177511
# D: {'prompt': 'Jak se řekne italsky výběrčí činže?', 'ans': 'VYGOOGLI', 'correction': 'PŘELOŽ'}
# == Acc: 0.8852459016393442, Loss: 0.5090408802116443
# D: {'prompt': 'Jak německy řekneš pivo?'}
# target: 6
# D: {'prompt': 'Jak německy řekneš pivo?', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Jak německy řekneš pivo?', 'ans': 'VYGOOGLI', 'correction': 'PŘELOŽ'}
# Sample Jak německy řekneš pivo? added to train. pt = 59
# Sample Jak německy řekneš pivo? added to dev.
# Final train loss: 0.014483309583738446, dev loss: 0.38113398337736726
# D: {'prompt': 'Jak německy řekneš pivo?', 'ans': 'VYGOOGLI', 'correction': 'PŘELOŽ'}
# == Acc: 0.9344262295081968, Loss: 0.35967057730933866
# D: {'prompt': 'Přelož do angličtiny slovo pes'}
# target: 4
# D: {'prompt': 'Přelož do angličtiny slovo pes', 'ans': 'PŘELOŽ'}
# D: {'prompt': 'Přelož do angličtiny slovo pes', 'ans': 'PŘELOŽ', 'correction': ''}
# Sample Přelož do angličtiny slovo pes added to train. pt = 60
# Sample Přelož do angličtiny slovo pes added to dev.
# Final train loss: 0.008025045390240848, dev loss: 0.3161774615291506
# D: {'prompt': 'Přelož do angličtiny slovo pes', 'ans': 'PŘELOŽ', 'correction': ''}
# == Acc: 0.9344262295081968, Loss: 0.31642361039097316
# D: {'prompt': 'Kolik lidí žije v Austrálii?'}
# target: 6
# D: {'prompt': 'Kolik lidí žije v Austrálii?', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Kolik lidí žije v Austrálii?', 'ans': 'VYGOOGLI', 'correction': ''}
# Sample Kolik lidí žije v Austrálii? added to train. pt = 61
# Sample Kolik lidí žije v Austrálii? added to dev.
# Final train loss: 0.006481217104010284, dev loss: 0.30061950255185366
# D: {'prompt': 'Kolik lidí žije v Austrálii?', 'ans': 'VYGOOGLI', 'correction': ''}
# == Acc: 0.9344262295081968, Loss: 0.31425099852246796
# D: {'prompt': 'Co je dnes za den?'}
# target: 0
# D: {'prompt': 'Co je dnes za den?', 'ans': 'KALENDÁŘ'}
# D: {'prompt': 'Co je dnes za den?', 'ans': 'KALENDÁŘ', 'correction': ''}
# Sample Co je dnes za den? added to train. pt = 62
# Sample Co je dnes za den? added to dev.
# Final train loss: 0.004758191935252398, dev loss: 1.9942569832317532
# D: {'prompt': 'Co je dnes za den?', 'ans': 'KALENDÁŘ', 'correction': ''}
# == Acc: 0.9344262295081968, Loss: 0.3233202214860434

# %%
for t, val in exp.items():
    print(f'== [t={round(t, 2)}] Acc = {val["acc"]}, OKs: ({len(val["oks"])})')
    for ok in val['oks']:
        print(ok)

for w in exp[max(list(exp.keys()))]['wrongs']:
    print(w)

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

labels = net.data.labels
print(labels)
COLORS = ['yellow', 'green', 'blue', 'purple', 'orange', 'maroon', 'cyan', 'brown', 'pink']
lab2COL = {label:col for label, col in zip(labels, COLORS)}

fig, ax = plt.subplots(2, 1, sharex = True)

# Taking the states at the end of each iteration
ts = sorted([key for key, val in exp.items() if val['step'] == 0 or val['phase'] in ('tuned', 'passed', 'retrained')])
steps = [exp[t]['step'] for t in ts]

# == AX0: Acc
ax[0].plot(ts, [exp[t]['acc'] for t in ts], 'ko-', linewidth='2')

for label in labels:
    try:
        acc_ = []
        for t in ts:
            if label in exp[t]['labels']:
                wr = len([w for w in exp[t]['wrongs'] if w[1] == label])
                ok = len([o for o in exp[t]['oks'] if o[1] == label])
                acc_.append(ok/(ok+wr))

        ax[0].plot(ts[-len(acc_):], acc_, '-', color=lab2COL[label])
    except ZeroDivisionError:
        print(f'W: label {label} not in test data.')

ax[0].set_title(f'# test \nsamples: {net.data.pk}', y=0.65, x=1.15)
ax[0].set_ylim([0, 1.1])
ax[0].set_ylabel('Test Accuracy')
ax[0].grid()

# == AX1: Samples
for label in labels:
    ns = [exp[t]['pt'][label] for t in ts if label in exp[t]['labels']]
    ax[1].plot(ts[-len(ns):], ns, '-', color=lab2COL[label])

#w = 0.2
#for t, step in zip(ts, steps):
#    if step % 1 == 0:
#        for li, label in enumerate(labels):
#            ax[1].bar(t-w*(len(labels)/2)+(w*li), exp[t]['pt'][label], width=w, color=lab2COL[label])

#ax[1].plot(steps, [net.data.pk]*len(steps), '--', color='darkgreen', linewidth='2')

ax[1].set_ylabel('# train samples')
#ax[1].set_ylim(bottom=0, top=max(n_train_max_)+2)
ax[1].set_xlabel('step')
ax[1].set_xticks([t for i, t in enumerate(ts) if i%3 == 0])
ax[1].set_xticklabels([s for i, s in enumerate(steps) if i%3 == 0])

ax[1].legend(
    bbox_to_anchor=(1.02, 1.55),
    handles=[mpatches.Patch(color='black', label='[mean]')]+[mpatches.Patch(color=lab2COL[label], label=label) for label in labels])

ax[1].grid()
axt = ax[1].twiny()
axt.set_xlabel('t (realtime) [s]')
ticklabels = [t for t in range(int(ts[-1])) if t % 30 == 0]
axt.set_xticks(ticklabels)
axt.set_xticklabels(ticklabels)

# Move twinned axis ticks and label from top to bottom
axt.xaxis.set_ticks_position("bottom")
axt.xaxis.set_label_position("bottom")

# Offset the twin axis below the host
axt.spines["bottom"].set_position(("axes", -0.45))

ax[0].text(-45, 1.15, '# classes', color='red')
ax[0].axvline(x=0, color='red', linestyle='--')
ax[1].axvline(x=0, color='red', linestyle='--')
ax[0].text(0, 1.15, exp[ts[0]]['m'], color='red')
for tim1, t in enumerate(ts[1:]):
    if exp[t]['m'] != exp[ts[tim1]]['m']:
        ax[0].axvline(x=t, color='red', linestyle='--')
        ax[1].axvline(x=t, color='red', linestyle='--')
        ax[0].text(t, 1.15, exp[t]['m'], color='red')

plt.show()
fig.savefig('from4-to7.jpg', bbox_inches='tight', dpi=350)
fig.savefig('from4-to7.eps', bbox_inches='tight')
# Out:
# ['KALENDÁŘ', 'POKYN', 'POZDRAV', 'POZNEJ', 'PŘELOŽ', 'STOP', 'VYGOOGLI']
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
