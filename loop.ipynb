# %%
import torch
import torch.nn as nn

from net_t2l import NetT2L, T2LModel
        
def load_pretrained(fn):
    return torch.load(fn)

def load_middleblock(fn):
    mod = torch.load(fn)
    mod.output_layer = nn.Identity()
    return mod

net = NetT2L()
#net = NetT2L(middleblock=load_middleblock(fn='model-intents-middleblock'))
#net = NetT2L(pretrained=load_pretrained(fn='model-intents-pretrained'))
#net = NetT2L(pretrained=load_pretrained(fn='model-intents-pretrained-m4'))
# Out:
# WARNING:root:No sentence-transformers model found with name /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /Users/kitt/.cache/torch/sentence_transformers/fav-kky_FERNET-C5 were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Required knowledge initialized: n = 768, m = 6, pt = 0, pk = 60, labels: {0: 'KALENDÁŘ', 1: 'POKYN', 2: 'POZDRAV', 3: 'POZNEJ', 4: 'STOP', 5: 'VYGOOGLI'}

# %%
from time import time

def now():
    return round(time()-t0, 2)

def shot(step, phase, t=None, **dialog):
    print('D:',dialog)
    loss, acc, wrongs, oks = net.evaluate(ret_wrongs=True, ret_oks=True)
    exp[t if t == 0 else now()] = {
        'step': step,
        'phase': phase,
        'labels': net.data.labels,
        'm': net.data.m,
        'pt': {label:net.data.data['train']['labels'].count(label) for label in net.data.labels},
        'loss': loss,
        'acc': acc,
        'wrongs': wrongs,
        'oks': oks,
        'dialog': dialog
    }

print('== Training loop ==')
exp = {}
steps = 100
t0 = time()

shot(step=0, phase='init', t=0)

for step in range(1, steps+1):
    ans = ''
    correction = ''
    prompt = input('\n\n> ')
    if prompt == 'done':
        break

    shot(step=step, phase='prompted', prompt=prompt)

    ans = net.predict(prompt)

    shot(step=step, phase='answered', prompt=prompt, ans=ans)

    correction = input(f'>> Ans: {ans} / Correct class (blank if OK): ')

    shot(step=step, phase='feedbacked', prompt=prompt, ans=ans, correction=correction)

    if correction:
        net.learn(sample=prompt, label=correction, verbose=False)
        shot(step=step, phase='retrained', prompt=prompt, ans=ans, correction=correction)
    else:
        if prompt not in net.data.data['train']['samples']:
            net.learn(sample=prompt, label=ans, verbose=False)
            shot(step=step, phase='tuned', prompt=prompt, ans=ans, correction=correction)
        else:
            shot(step=step, phase='passed', prompt=prompt, ans=ans, correction=correction)

    loss, acc = net.evaluate()
    print(f'== Acc: {acc}, Loss: {loss}')
# Out:
# == Training loop ==
# D: {}
# D: {'prompt': 'Ahoj'}
# target: 1
# D: {'prompt': 'Ahoj', 'ans': 'POKYN'}
# D: {'prompt': 'Ahoj', 'ans': 'POKYN', 'correction': 'POZDRAV'}
# Final train loss: 0.3992419441541036, dev loss: 2.061050683259964
# D: {'prompt': 'Ahoj', 'ans': 'POKYN', 'correction': 'POZDRAV'}
# == Acc: 0.6666666666666666, Loss: 2.065649934858084
# D: {'prompt': 'Čau'}
# target: 2
# D: {'prompt': 'Čau', 'ans': 'POZDRAV'}
# D: {'prompt': 'Čau', 'ans': 'POZDRAV', 'correction': ''}
# D: {'prompt': 'Čau', 'ans': 'POZDRAV', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.065649934858084
# D: {'prompt': 'Najdi město v ČR'}
# target: 5
# D: {'prompt': 'Najdi město v ČR', 'ans': 'VYGOOGLI'}
# D: {'prompt': 'Najdi město v ČR', 'ans': 'VYGOOGLI', 'correction': ''}
# Sample Najdi město v ČR added to train. pt = 41
# Sample Najdi město v ČR added to dev.
# Final train loss: 0.1972814748684565, dev loss: 2.2847401797771454
# D: {'prompt': 'Najdi město v ČR', 'ans': 'VYGOOGLI', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.3139628366877636
# D: {'prompt': 'Stop'}
# target: 4
# D: {'prompt': 'Stop', 'ans': 'STOP'}
# D: {'prompt': 'Stop', 'ans': 'STOP', 'correction': ''}
# D: {'prompt': 'Stop', 'ans': 'STOP', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.3139628366877636
# D: {'prompt': 'Zastav'}
# target: 4
# D: {'prompt': 'Zastav', 'ans': 'STOP'}
# D: {'prompt': 'Zastav', 'ans': 'STOP', 'correction': ''}
# D: {'prompt': 'Zastav', 'ans': 'STOP', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.3139628366877636
# D: {'prompt': 'Co mám v ruce za předmět?'}
# target: 0
# D: {'prompt': 'Co mám v ruce za předmět?', 'ans': 'KALENDÁŘ'}
# D: {'prompt': 'Co mám v ruce za předmět?', 'ans': 'KALENDÁŘ', 'correction': 'POZNEJ'}
# Sample Co mám v ruce za předmět? added to train. pt = 42
# Sample Co mám v ruce za předmět? added to dev.
# Final train loss: 0.084647203485171, dev loss: 1.9713241308927536
# D: {'prompt': 'Co mám v ruce za předmět?', 'ans': 'KALENDÁŘ', 'correction': 'POZNEJ'}
# == Acc: 0.6666666666666666, Loss: 2.0220514977971713
# D: {'prompt': 'Co to držím v ruce?'}
# target: 3
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ'}
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ', 'correction': ''}
# Sample Co to držím v ruce? added to train. pt = 43
# Sample Co to držím v ruce? added to dev.
# Final train loss: 0.051325863848129906, dev loss: 2.016874074935913
# D: {'prompt': 'Co to držím v ruce?', 'ans': 'POZNEJ', 'correction': ''}
# == Acc: 0.6666666666666666, Loss: 2.1188625797008473

# %%
for t, val in exp.items():
    print(f'== [t={round(t, 2)}] Acc = {val["acc"]}, OKs: ({len(val["oks"])})')
    for ok in val['oks']:
        print(ok)

for w in exp[max(list(exp.keys()))]['wrongs']:
    print(w)
# Out:
# == [t=0] Acc = 0.15, OKs: (9)
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Zastav se', 'STOP')
# ('Vypnout', 'STOP')
# ('Stop', 'STOP')
# ('Ukonči se', 'STOP')
# ('Dost', 'STOP')
# ('Dobrý den', 'POZDRAV')
# ('Zastav', 'STOP')
# ('Konec', 'STOP')
# == [t=3.17] Acc = 0.15, OKs: (9)
# ('Zastav se', 'STOP')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Konec', 'STOP')
# ('Stop', 'STOP')
# ('Dobrý den', 'POZDRAV')
# ('Dost', 'STOP')
# ('Vypnout', 'STOP')
# ('Zastav', 'STOP')
# ('Ukonči se', 'STOP')
# == [t=3.24] Acc = 0.15, OKs: (9)
# ('Dost', 'STOP')
# ('Ukonči se', 'STOP')
# ('Vypnout', 'STOP')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Zastav', 'STOP')
# ('Konec', 'STOP')
# ('Dobrý den', 'POZDRAV')
# ('Zastav se', 'STOP')
# ('Stop', 'STOP')
# == [t=5.24] Acc = 0.15, OKs: (9)
# ('Stop', 'STOP')
# ('Ukonči se', 'STOP')
# ('Konec', 'STOP')
# ('Zastav', 'STOP')
# ('Vypnout', 'STOP')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dost', 'STOP')
# ('Zastav se', 'STOP')
# ('Dobrý den', 'POZDRAV')
# == [t=5.35] Acc = 0.16666666666666666, OKs: (10)
# ('Dobrý den', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# == [t=10.86] Acc = 0.16666666666666666, OKs: (10)
# ('Dobrej', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# == [t=10.92] Acc = 0.16666666666666666, OKs: (10)
# ('Zdar', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# == [t=11.61] Acc = 0.16666666666666666, OKs: (10)
# ('Zdravíčko', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# == [t=11.72] Acc = 0.16666666666666666, OKs: (10)
# ('Zdravíčko', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# == [t=18.25] Acc = 0.16666666666666666, OKs: (10)
# ('Dobrej', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# == [t=18.32] Acc = 0.16666666666666666, OKs: (10)
# ('Dobrý den', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# == [t=20.58] Acc = 0.16666666666666666, OKs: (10)
# ('Zdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# == [t=20.78] Acc = 0.2833333333333333, OKs: (17)
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrej', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# == [t=29.0] Acc = 0.2833333333333333, OKs: (17)
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Zdravíčko', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# == [t=29.08] Acc = 0.2833333333333333, OKs: (17)
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrej', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Zdravíčko', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# == [t=29.74] Acc = 0.2833333333333333, OKs: (17)
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# == [t=29.9] Acc = 0.2833333333333333, OKs: (17)
# ('Dobrej', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Zdravíčko', 'POZDRAV')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# == [t=32.93] Acc = 0.2833333333333333, OKs: (17)
# ('Dobrej', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# == [t=32.99] Acc = 0.2833333333333333, OKs: (17)
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# == [t=34.63] Acc = 0.2833333333333333, OKs: (17)
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Zdravíčko', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Dobrej', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# == [t=34.83] Acc = 0.2833333333333333, OKs: (17)
# ('Dobrej', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# == [t=38.58] Acc = 0.2833333333333333, OKs: (17)
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# == [t=38.68] Acc = 0.2833333333333333, OKs: (17)
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# == [t=40.45] Acc = 0.2833333333333333, OKs: (17)
# ('Dobré ráno', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrej', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# == [t=40.61] Acc = 0.3333333333333333, OKs: (20)
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Ahoj', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# == [t=46.54] Acc = 0.3333333333333333, OKs: (20)
# ('Ahoj', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# == [t=46.61] Acc = 0.3333333333333333, OKs: (20)
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# == [t=47.25] Acc = 0.3333333333333333, OKs: (20)
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# == [t=47.42] Acc = 0.35, OKs: (21)
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# == [t=53.9] Acc = 0.35, OKs: (21)
# ('Dobrý večer', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jaký je rok', 'KALENDÁŘ')
# == [t=53.97] Acc = 0.35, OKs: (21)
# ('Zdravíčko', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# == [t=54.67] Acc = 0.35, OKs: (21)
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Čau', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# == [t=54.79] Acc = 0.4, OKs: (24)
# ('Dobrej', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Ahoj', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Zdar', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# == [t=57.53] Acc = 0.4, OKs: (24)
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Ahoj', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Zdar', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# == [t=57.59] Acc = 0.4, OKs: (24)
# ('Dobrej', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Ahoj', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# == [t=60.51] Acc = 0.4, OKs: (24)
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Zdar', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Čau', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# == [t=60.68] Acc = 0.4, OKs: (24)
# ('Ahoj', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Zdravíčko', 'POZDRAV')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Dobrej', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Čau', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# == [t=67.11] Acc = 0.4, OKs: (24)
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Zdar', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Dobrý večer', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Čau', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# == [t=67.18] Acc = 0.4, OKs: (24)
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Dobré ráno', 'POZDRAV')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Ahoj', 'POZDRAV')
# ('Nazdar', 'POZDRAV')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Dobrý den', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Čau', 'POZDRAV')
# ('Dobrej', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Dobrý večer', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# == [t=67.98] Acc = 0.4, OKs: (24)
# ('Nazdar', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Dobrý večer', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Kolikátého je dnes', 'KALENDÁŘ')
# ('Zdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Dobrej', 'POZDRAV')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Dobré ráno', 'POZDRAV')
# ('Dobrý den', 'POZDRAV')
# ('Zdravíčko', 'POZDRAV')
# == [t=68.17] Acc = 0.38333333333333336, OKs: (23)
# ('Dobrý večer', 'POZDRAV')
# ('Dobré ráno', 'POZDRAV')
# ('Kdo má dnes narozeniny', 'KALENDÁŘ')
# ('Nazdar', 'POZDRAV')
# ('Pozdrav pánbůh', 'POZDRAV')
# ('Kde koupit bitcoin za CZK a jaký je aktuální kurz', 'VYGOOGLI')
# ('Kolik je hodin', 'KALENDÁŘ')
# ('Naplánuj schůzku na pátek ve 3', 'KALENDÁŘ')
# ('Dobrej', 'POZDRAV')
# ('Ahoj', 'POZDRAV')
# ('Kolik je států v Africe', 'VYGOOGLI')
# ('Dobrý den', 'POZDRAV')
# ('Zdar', 'POZDRAV')
# ('Jaký je rok', 'KALENDÁŘ')
# ('Jak vybrat běžky', 'VYGOOGLI')
# ('Co je dnes za den', 'KALENDÁŘ')
# ('Najdi mi restauraci v Brně', 'VYGOOGLI')
# ('Jaký je počet obyvatel v Plzni', 'VYGOOGLI')
# ('Kdo má dnes svátek', 'KALENDÁŘ')
# ('Zdravíčko', 'POZDRAV')
# ('Kdo je prezident ve Francii', 'VYGOOGLI')
# ('Čau', 'POZDRAV')
# ('Jaký je datum', 'KALENDÁŘ')
# ('Dost', 'STOP', 'POZDRAV')
# ('Co to je?', 'POZNEJ', 'VYGOOGLI')
# ('Jak vydělat peníze', 'VYGOOGLI', 'POZDRAV')
# ('Co je za měsíc', 'KALENDÁŘ', 'VYGOOGLI')
# ('Zamávej', 'POKYN', 'POZDRAV')
# ('Zvedni pravou ruku', 'POKYN', 'POZDRAV')
# ('Kde budou další olympijské hry', 'VYGOOGLI', 'KALENDÁŘ')
# ('Zvedni levou ruku', 'POKYN', 'POZDRAV')
# ('Poznej, co to je', 'POZNEJ', 'VYGOOGLI')
# ('Poznej předmět', 'POZNEJ', 'VYGOOGLI')
# ('Co vidíš', 'POZNEJ', 'POZDRAV')
# ('Rozsviť LED', 'POKYN', 'POZDRAV')
# ('Stop', 'STOP', 'POZDRAV')
# ('Otoč se', 'POKYN', 'POZDRAV')
# ('Ukončit', 'STOP', 'POZDRAV')
# ('Jak rychle zhubnout', 'VYGOOGLI', 'POZDRAV')
# ('Co to držím', 'POZNEJ', 'VYGOOGLI')
# ('Jak napsat životopis', 'VYGOOGLI', 'POZDRAV')
# ('Jaký je to předmět', 'POZNEJ', 'VYGOOGLI')
# ('Jaká je to věc', 'POZNEJ', 'POZDRAV')
# ('Zastav se', 'STOP', 'POZDRAV')
# ('Kolikátého je dnes', 'KALENDÁŘ', 'VYGOOGLI')
# ('Zablikej', 'POKYN', 'POZDRAV')
# ('Ukonči se', 'STOP', 'POZDRAV')
# ('Urči, o co se jedná', 'POZNEJ', 'VYGOOGLI')
# ('Rozjeď se', 'POKYN', 'POZDRAV')
# ('Zapískej', 'POKYN', 'POZDRAV')
# ('Konec', 'STOP', 'POZDRAV')
# ('Zastav', 'STOP', 'POZDRAV')
# ('Co je tohle', 'POZNEJ', 'POZDRAV')
# ('Zatoč', 'POKYN', 'POZDRAV')
# ('Co mám v plánu zítra odpoledne', 'KALENDÁŘ', 'VYGOOGLI')
# ('Přestaň', 'STOP', 'POZDRAV')
# ('Vypni se', 'STOP', 'POZDRAV')
# ('Vypnout', 'STOP', 'POZDRAV')
# ('Co to mám', 'POZNEJ', 'VYGOOGLI')
# ('Jdi vpřed', 'POKYN', 'POZDRAV')

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

labels = net.data.labels
print(labels)
COLORS = ['yellow', 'green', 'blue', 'purple', 'orange', 'maroon', 'cyan', 'brown', 'pink']
lab2COL = {label:col for label, col in zip(labels, COLORS)}

fig, ax = plt.subplots(2, 1, sharex = True)

# Taking the states at the end of each iteration
ts = sorted([key for key, val in exp.items() if val['step'] == 0 or val['phase'] in ('tuned', 'passed', 'retrained')])
steps = [exp[t]['step'] for t in ts]

# == AX0: Acc
ax[0].plot(ts, [exp[t]['acc'] for t in ts], 'ko-', linewidth='2')

for label in labels:
    try:
        acc_ = []
        for t in ts:
            if label in exp[t]['labels']:
                wr = len([w for w in exp[t]['wrongs'] if w[1] == label])
                ok = len([o for o in exp[t]['oks'] if o[1] == label])
                acc_.append(ok/(ok+wr))

        ax[0].plot(ts[-len(acc_):], acc_, '-', color=lab2COL[label])
    except ZeroDivisionError:
        print(f'W: label {label} not in test data.')
        

ax[0].set_title(f'# test \nsamples: {net.data.pk}', y=0.65, x=1.15)
ax[0].set_ylim([0, 1.1])
ax[0].set_ylabel('Test Accuracy')
ax[0].grid()

# == AX1: Samples
for label in labels:
    ns = [exp[t]['pt'][label] for t in ts if label in exp[t]['labels']]
    ax[1].plot(ts[-len(ns):], ns, '-', color=lab2COL[label])

#w = 0.2
#for t, step in zip(ts, steps):
#    if step % 1 == 0:
#        for li, label in enumerate(labels):
#            ax[1].bar(t-w*(len(labels)/2)+(w*li), exp[t]['pt'][label], width=w, color=lab2COL[label])

#ax[1].plot(steps, [net.data.pk]*len(steps), '--', color='darkgreen', linewidth='2')

ax[1].set_ylabel('# train samples')
#ax[1].set_ylim(bottom=0, top=max(n_train_max_)+2)
ax[1].set_xlabel('step')
ax[1].set_xticks([t for i, t in enumerate(ts) if i%3 == 0])
ax[1].set_xticklabels([s for i, s in enumerate(steps) if i%3 == 0])

ax[1].legend(
    bbox_to_anchor=(1.02, 1.55),
    handles=[mpatches.Patch(color='black', label='[mean]')]+[mpatches.Patch(color=lab2COL[label], label=label) for label in labels])

ax[1].grid()
axt = ax[1].twiny()
axt.set_xlabel('t (realtime) [s]')
ticklabels = [t for t in range(int(ts[-1])) if t % 30 == 0]
axt.set_xticks(ticklabels)
axt.set_xticklabels(ticklabels)

# Move twinned axis ticks and label from top to bottom
axt.xaxis.set_ticks_position("bottom")
axt.xaxis.set_label_position("bottom")

# Offset the twin axis below the host
axt.spines["bottom"].set_position(("axes", -0.45))

ax[0].text(-45, 1.15, '# classes', color='red')
ax[0].axvline(x=0, color='red', linestyle='--')
ax[1].axvline(x=0, color='red', linestyle='--')
ax[0].text(0, 1.15, exp[ts[0]]['m'], color='red')
for tim1, t in enumerate(ts[1:]):
    if exp[t]['m'] != exp[ts[tim1]]['m']:
        ax[0].axvline(x=t, color='red', linestyle='--')
        ax[1].axvline(x=t, color='red', linestyle='--')
        ax[0].text(t, 1.15, exp[t]['m'], color='red')

plt.show()
fig.savefig('test.jpg', bbox_inches='tight', dpi=350)
fig.savefig('test.eps', bbox_inches='tight')
# Out:
# ['KALENDÁŘ', 'POKYN', 'POZDRAV', 'POZNEJ', 'STOP', 'VYGOOGLI']
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
